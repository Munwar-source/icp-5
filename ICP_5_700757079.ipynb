# %%
from keras.layers import Input, Dense
from keras.models import Model

# this is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)
# this model maps an input to its reconstruction
autoencoder = Model(input_img, decoded)
# this model maps an input to its encoded representation
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
from keras.datasets import mnist, fashion_mnist
import numpy as np
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

autoencoder.fit(x_train, x_train,
                epochs=5,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/5
# 235/235 [==============================] - 10s 33ms/step - loss: 0.6950 - val_loss: 0.6949
# Epoch 2/5
# 235/235 [==============================] - 5s 22ms/step - loss: 0.6949 - val_loss: 0.6948
# Epoch 3/5
# 235/235 [==============================] - 5s 20ms/step - loss: 0.6947 - val_loss: 0.6946
# Epoch 4/5
# 235/235 [==============================] - 7s 29ms/step - loss: 0.6946 - val_loss: 0.6945
# Epoch 5/5
# 235/235 [==============================] - 6s 25ms/step - loss: 0.6945 - val_loss: 0.6944

# %%
from keras.layers import Input, Dense
from keras.models import Model

# Define the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# Input placeholder
input_img = Input(shape=(784,))
# Encoded representation
encoded = Dense(128, activation='relu')(input_img)  # New hidden layer with 128 neurons
encoded = Dense(encoding_dim, activation='relu')(encoded)  # Encoding layer

# Decoded representation
decoded = Dense(128, activation='relu')(encoded)  # New hidden layer with 128 neurons
decoded = Dense(784, activation='sigmoid')(decoded)  # Decoding layer

# Autoencoder model
autoencoder = Model(input_img, decoded)

# Compile autoencoder
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# Load and preprocess Fashion MNIST dataset
from keras.datasets import fashion_mnist
import numpy as np

(x_train, _), (x_test, _) = fashion_mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Train the autoencoder
autoencoder.fit(x_train, x_train,
                epochs=5,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
loss = autoencoder.evaluate(x_test, x_test)
print(f'Test loss: {loss}')
# Out:
# Epoch 1/5
# 235/235 [==============================] - 13s 47ms/step - loss: 0.6946 - val_loss: 0.6946
# Epoch 2/5
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6945 - val_loss: 0.6944
# Epoch 3/5
# 235/235 [==============================] - 5s 21ms/step - loss: 0.6944 - val_loss: 0.6943
# Epoch 4/5
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6942 - val_loss: 0.6942
# Epoch 5/5
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6941 - val_loss: 0.6940
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6940
# Test loss: 0.6940216422080994

# %%
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import Adam
from keras.datasets import fashion_mnist
import numpy as np

# Define the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# Input placeholder
input_img = Input(shape=(784,))
# Encoded representation
encoded = Dense(128, activation='relu')(input_img)  # New hidden layer with 128 neurons
encoded = Dense(encoding_dim, activation='relu')(encoded)  # Encoding layer

# Decoded representation
decoded = Dense(128, activation='relu')(encoded)  # New hidden layer with 128 neurons
decoded = Dense(784, activation='sigmoid')(decoded)  # Decoding layer

# Autoencoder model
autoencoder = Model(input_img, decoded)

# Compile autoencoder with Adam optimizer and adjusted learning rate
autoencoder.compile(optimizer=Adam(lr=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Load and preprocess Fashion MNIST dataset
(x_train, _), (x_test, _) = fashion_mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Train the autoencoder with adjusted batch size and number of epochs
history = autoencoder.fit(x_train, x_train,
                          epochs=15,  # Increased number of epochs
                          batch_size=128,  # Adjusted batch size
                          shuffle=True,
                          validation_data=(x_test, x_test))

# Evaluate performance on test data
loss, accuracy = autoencoder.evaluate(x_test, x_test)
print(f'Test loss: {loss:.4f}')
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/15
# 469/469 [==============================] - 8s 14ms/step - loss: 0.3411 - accuracy: 0.0112 - val_loss: 0.3037 - val_accuracy: 0.0141
# Epoch 2/15
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2956 - accuracy: 0.0144 - val_loss: 0.2933 - val_accuracy: 0.0190
# Epoch 3/15
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2887 - accuracy: 0.0175 - val_loss: 0.2884 - val_accuracy: 0.0210
# Epoch 4/15
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2848 - accuracy: 0.0207 - val_loss: 0.2854 - val_accuracy: 0.0222
# Epoch 5/15
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2823 - accuracy: 0.0228 - val_loss: 0.2835 - val_accuracy: 0.0214
# Epoch 6/15
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2805 - accuracy: 0.0242 - val_loss: 0.2824 - val_accuracy: 0.0238
# Epoch 7/15
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2793 - accuracy: 0.0259 - val_loss: 0.2808 - val_accuracy: 0.0267
# Epoch 8/15
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2782 - accuracy: 0.0274 - val_loss: 0.2800 - val_accuracy: 0.0310
# Epoch 9/15
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2774 - accuracy: 0.0280 - val_loss: 0.2793 - val_accuracy: 0.0260
# Epoch 10/15
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2767 - accuracy: 0.0282 - val_loss: 0.2786 - val_accuracy: 0.0296
# Epoch 11/15
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2762 - accuracy: 0.0287 - val_loss: 0.2781 - val_accuracy: 0.0291
# Epoch 12/15
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2757 - accuracy: 0.0294 - val_loss: 0.2786 - val_accuracy: 0.0336
# Epoch 13/15
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2753 - accuracy: 0.0305 - val_loss: 0.2774 - val_accuracy: 0.0293
# Epoch 14/15
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2750 - accuracy: 0.0298 - val_loss: 0.2771 - val_accuracy: 0.0339
# Epoch 15/15
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2746 - accuracy: 0.0304 - val_loss: 0.2769 - val_accuracy: 0.0327
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2769 - accuracy: 0.0327
# Test loss: 0.2769

# %%
import matplotlib.pyplot as plt

# Predict on test data
decoded_imgs = autoencoder.predict(x_test)

# Number of images to display
num_images = 5

# Plot original images and reconstructed images
plt.figure(figsize=(10, 4))

for i in range(num_images):
    # Original images
    plt.subplot(2, num_images, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title('Original')
    plt.axis('off')

    # Reconstructed images
    plt.subplot(2, num_images, i + 1 + num_images)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    plt.title('Reconstructed')
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %%
from keras.layers import Input, Dense
from keras.models import Model

# Define the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# Input placeholder
input_img = Input(shape=(784,))

# Encoder layers
encoded = Dense(128, activation='relu')(input_img)  # Add a hidden layer with 128 neurons
encoded = Dense(encoding_dim, activation='relu')(encoded)  # Encoding layer

# Decoder layers
decoded = Dense(128, activation='relu')(encoded)  # Add a hidden layer with 128 neurons
decoded = Dense(784, activation='sigmoid')(decoded)  # Decoding layer

# Autoencoder model
autoencoder = Model(input_img, decoded)

# Compile the autoencoder
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# Load and preprocess Fashion MNIST dataset
from keras.datasets import fashion_mnist
import numpy as np

(x_train, _), (x_test, _) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Introducing noise to the data
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

# Train the autoencoder
autoencoder.fit(x_train_noisy, x_train,
                epochs=10,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test_noisy, x_test_noisy))
# Out:
# Epoch 1/10
# 235/235 [==============================] - 5s 18ms/step - loss: 0.6945 - val_loss: 0.6944
# Epoch 2/10
# 235/235 [==============================] - 5s 22ms/step - loss: 0.6942 - val_loss: 0.6941
# Epoch 3/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6940 - val_loss: 0.6939
# Epoch 4/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6938 - val_loss: 0.6936
# Epoch 5/10
# 235/235 [==============================] - 5s 23ms/step - loss: 0.6935 - val_loss: 0.6934
# Epoch 6/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6933 - val_loss: 0.6932
# Epoch 7/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6931 - val_loss: 0.6930
# Epoch 8/10
# 235/235 [==============================] - 5s 23ms/step - loss: 0.6929 - val_loss: 0.6928
# Epoch 9/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6927 - val_loss: 0.6925
# Epoch 10/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6924 - val_loss: 0.6923

# %%
from keras.layers import Input, Dense
from keras.models import Model

# Define the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# Input placeholder
input_img = Input(shape=(784,))

# Encoder layers
encoded = Dense(256, activation='relu')(input_img)  # Add a hidden layer with 128 neurons
encoded = Dense(encoding_dim, activation='relu')(encoded)  # Encoding layer

# Decoder layers
decoded = Dense(256, activation='relu')(encoded)  # Add a hidden layer with 128 neurons
decoded = Dense(784, activation='sigmoid')(decoded)  # Decoding layer

# Autoencoder model
autoencoder = Model(input_img, decoded)

# Compile the autoencoder
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# Load and preprocess Fashion MNIST dataset
from keras.datasets import fashion_mnist
import numpy as np

(x_train, _), (x_test, _) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Introducing noise to the data
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

# Train the autoencoder
history = autoencoder.fit(x_train_noisy, x_train,
                          epochs=10,
                          batch_size=256,
                          shuffle=True,
                          validation_data=(x_test_noisy, x_test_noisy))
# Out:
# Epoch 1/10
# 235/235 [==============================] - 7s 25ms/step - loss: 0.6997 - val_loss: 0.6994
# Epoch 2/10
# 235/235 [==============================] - 6s 28ms/step - loss: 0.6991 - val_loss: 0.6988
# Epoch 3/10
# 235/235 [==============================] - 6s 26ms/step - loss: 0.6986 - val_loss: 0.6983
# Epoch 4/10
# 235/235 [==============================] - 6s 25ms/step - loss: 0.6980 - val_loss: 0.6978
# Epoch 5/10
# 235/235 [==============================] - 7s 30ms/step - loss: 0.6975 - val_loss: 0.6973
# Epoch 6/10
# 235/235 [==============================] - 5s 23ms/step - loss: 0.6970 - val_loss: 0.6968
# Epoch 7/10
# 235/235 [==============================] - 8s 34ms/step - loss: 0.6966 - val_loss: 0.6963
# Epoch 8/10
# 235/235 [==============================] - 6s 25ms/step - loss: 0.6961 - val_loss: 0.6959
# Epoch 9/10
# 235/235 [==============================] - 7s 31ms/step - loss: 0.6957 - val_loss: 0.6955
# Epoch 10/10
# 235/235 [==============================] - 6s 25ms/step - loss: 0.6953 - val_loss: 0.6951

# %%
from keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.models import Model
from keras.optimizers import Adam
from keras.datasets import fashion_mnist
import numpy as np

# Define the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# Input placeholder
input_img = Input(shape=(784,))

# Encoder layers
encoded = Dense(512, activation='relu')(input_img)
encoded = BatchNormalization()(encoded)
encoded = Dense(encoding_dim, activation='relu')(encoded)

# Decoder layers
decoded = Dense(512, activation='relu')(encoded)
decoded = BatchNormalization()(decoded)
decoded = Dense(784, activation='sigmoid')(decoded)

# Autoencoder model
autoencoder = Model(input_img, decoded)

# Compile the autoencoder
autoencoder.compile(optimizer=Adam(lr=0.001), loss='binary_crossentropy')

# Load and preprocess Fashion MNIST dataset
(x_train, _), (x_test, _) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Introducing noise to the data
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

# Train the autoencoder
history = autoencoder.fit(x_train_noisy, x_train,
                          epochs=20,  # Increased epochs
                          batch_size=256,
                          shuffle=True,
                          validation_data=(x_test_noisy, x_test_noisy))
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/20
# 235/235 [==============================] - 12s 47ms/step - loss: 0.3833 - val_loss: 0.2935
# Epoch 2/20
# 235/235 [==============================] - 11s 46ms/step - loss: 0.3014 - val_loss: 0.2742
# Epoch 3/20
# 235/235 [==============================] - 10s 41ms/step - loss: 0.2965 - val_loss: 0.2688
# Epoch 4/20
# 235/235 [==============================] - 10s 43ms/step - loss: 0.2936 - val_loss: 0.2651
# Epoch 5/20
# 235/235 [==============================] - 11s 46ms/step - loss: 0.2916 - val_loss: 0.2619
# Epoch 6/20
# 235/235 [==============================] - 11s 46ms/step - loss: 0.2904 - val_loss: 0.2596
# Epoch 7/20
# 235/235 [==============================] - 10s 43ms/step - loss: 0.2892 - val_loss: 0.2590
# Epoch 8/20
# 235/235 [==============================] - 10s 42ms/step - loss: 0.2881 - val_loss: 0.2572
# Epoch 9/20
# 235/235 [==============================] - 13s 55ms/step - loss: 0.2875 - val_loss: 0.2559
# Epoch 10/20
# 235/235 [==============================] - 11s 47ms/step - loss: 0.2867 - val_loss: 0.2551
# Epoch 11/20
# 235/235 [==============================] - 11s 47ms/step - loss: 0.2862 - val_loss: 0.2539
# Epoch 12/20
# 235/235 [==============================] - 9s 39ms/step - loss: 0.2855 - val_loss: 0.2536
# Epoch 13/20
# 235/235 [==============================] - 11s 46ms/step - loss: 0.2852 - val_loss: 0.2539
# Epoch 14/20
# 235/235 [==============================] - 11s 46ms/step - loss: 0.2847 - val_loss: 0.2539
# Epoch 15/20
# 235/235 [==============================] - 11s 47ms/step - loss: 0.2844 - val_loss: 0.2532
# Epoch 16/20
# 235/235 [==============================] - 9s 40ms/step - loss: 0.2842 - val_loss: 0.2528
# Epoch 17/20
# 235/235 [==============================] - 11s 45ms/step - loss: 0.2837 - val_loss: 0.2527
# Epoch 18/20
# 235/235 [==============================] - 11s 46ms/step - loss: 0.2832 - val_loss: 0.2528
# Epoch 19/20
# 235/235 [==============================] - 11s 46ms/step - loss: 0.2831 - val_loss: 0.2518
# Epoch 20/20
# 235/235 [==============================] - 9s 40ms/step - loss: 0.2828 - val_loss: 0.2513

# %%
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import fashion_mnist
import numpy as np
import matplotlib.pyplot as plt

# Load data
(x_train, _), (x_test, _) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Define autoencoder with an additional hidden layer
encoding_dim = 32  # Compression factor
input_img = Input(shape=(784,))
encoded = Dense(128, activation='relu')(input_img)  # First hidden layer
encoded = Dense(encoding_dim, activation='relu')(encoded)  # Second hidden layer (encoding)
decoded = Dense(128, activation='relu')(encoded)  # First decoding layer
decoded = Dense(784, activation='sigmoid')(decoded)  # Output layer

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')  # Changed optimizer to Adam

# Train autoencoder
history = autoencoder.fit(x_train, x_train,
                          epochs=100,  # Increased epochs
                          batch_size=256,
                          shuffle=True,
                          validation_data=(x_test, x_test))

# Predict and visualize
decoded_imgs = autoencoder.predict(x_test)

# Visualize original and reconstructed images
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Reconstructed
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# Implement a denoising autoencoder
noise_factor = 0.2  # Reduced noise factor
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# Redefine autoencoder for denoising
input_img_noisy = Input(shape=(784,))
encoded_noisy = Dense(128, activation='relu')(input_img_noisy)
encoded_noisy = Dense(encoding_dim, activation='relu')(encoded_noisy)
decoded_noisy = Dense(128, activation='relu')(encoded_noisy)
decoded_noisy = Dense(784, activation='sigmoid')(decoded_noisy)

denoising_autoencoder = Model(input_img_noisy, decoded_noisy)
denoising_autoencoder.compile(optimizer='adam', loss='binary_crossentropy')  # Changed optimizer to Adam

# Train denoising autoencoder
history_denoising = denoising_autoencoder.fit(x_train_noisy, x_train,
                                              epochs=100,  # Increased epochs
                                              batch_size=256,
                                              shuffle=True,
                                              validation_data=(x_test_noisy, x_test))

# Predict and visualize denoised images
denoised_imgs = denoising_autoencoder.predict(x_test_noisy)

plt.figure(figsize=(20, 4))
for i in range(n):
    # Noisy image
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Reconstructed image
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(denoised_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# Plot loss and accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_denoising.history['loss'], label='Denoising Training Loss')
plt.plot(history_denoising.history['val_loss'], label='Denoising Validation Loss')
plt.title('Denoising Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/100
# 235/235 [==============================] - 5s 16ms/step - loss: 0.3695 - val_loss: 0.3152
# Epoch 2/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.3051 - val_loss: 0.3016
# Epoch 3/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2962 - val_loss: 0.2953
# Epoch 4/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2910 - val_loss: 0.2914
# Epoch 5/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2879 - val_loss: 0.2895
# Epoch 6/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2857 - val_loss: 0.2871
# Epoch 7/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2841 - val_loss: 0.2855
# Epoch 8/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2828 - val_loss: 0.2844
# Epoch 9/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2817 - val_loss: 0.2837
# Epoch 10/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2809 - val_loss: 0.2826
# Epoch 11/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2800 - val_loss: 0.2820
# Epoch 12/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2793 - val_loss: 0.2812
# Epoch 13/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2788 - val_loss: 0.2807
# Epoch 14/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2782 - val_loss: 0.2803
# Epoch 15/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2776 - val_loss: 0.2798
# Epoch 16/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2773 - val_loss: 0.2795
# Epoch 17/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2768 - val_loss: 0.2791
# Epoch 18/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2765 - val_loss: 0.2802
# Epoch 19/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2762 - val_loss: 0.2783
# Epoch 20/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2759 - val_loss: 0.2781
# Epoch 21/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2756 - val_loss: 0.2779
# Epoch 22/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2754 - val_loss: 0.2777
# Epoch 23/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2752 - val_loss: 0.2774
# Epoch 24/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2749 - val_loss: 0.2775
# Epoch 25/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2748 - val_loss: 0.2770
# Epoch 26/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2745 - val_loss: 0.2772
# Epoch 27/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2744 - val_loss: 0.2766
# Epoch 28/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2742 - val_loss: 0.2767
# Epoch 29/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2741 - val_loss: 0.2764
# Epoch 30/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2739 - val_loss: 0.2764
# Epoch 31/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2738 - val_loss: 0.2764
# Epoch 32/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2736 - val_loss: 0.2762
# Epoch 33/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2735 - val_loss: 0.2760
# Epoch 34/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2734 - val_loss: 0.2759
# Epoch 35/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2733 - val_loss: 0.2759
# Epoch 36/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2732 - val_loss: 0.2755
# Epoch 37/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2731 - val_loss: 0.2754
# Epoch 38/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2730 - val_loss: 0.2755
# Epoch 39/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2728 - val_loss: 0.2753
# Epoch 40/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2727 - val_loss: 0.2753
# Epoch 41/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2727 - val_loss: 0.2753
# Epoch 42/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2726 - val_loss: 0.2752
# Epoch 43/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2725 - val_loss: 0.2751
# Epoch 44/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2724 - val_loss: 0.2748
# Epoch 45/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2723 - val_loss: 0.2751
# Epoch 46/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2722 - val_loss: 0.2747
# Epoch 47/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2721 - val_loss: 0.2746
# Epoch 48/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2721 - val_loss: 0.2747
# Epoch 49/100
# 235/235 [==============================] - 5s 23ms/step - loss: 0.2720 - val_loss: 0.2745
# Epoch 50/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2719 - val_loss: 0.2745
# Epoch 51/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2718 - val_loss: 0.2745
# Epoch 52/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2718 - val_loss: 0.2743
# Epoch 53/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2717 - val_loss: 0.2742
# Epoch 54/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2716 - val_loss: 0.2741
# Epoch 55/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2715 - val_loss: 0.2740
# Epoch 56/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2714 - val_loss: 0.2744
# Epoch 57/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2713 - val_loss: 0.2739
# Epoch 58/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2713 - val_loss: 0.2740
# Epoch 59/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2712 - val_loss: 0.2739
# Epoch 60/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2712 - val_loss: 0.2742
# Epoch 61/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2711 - val_loss: 0.2737
# Epoch 62/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2710 - val_loss: 0.2736
# Epoch 63/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2710 - val_loss: 0.2736
# Epoch 64/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2709 - val_loss: 0.2735
# Epoch 65/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2709 - val_loss: 0.2735
# Epoch 66/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2708 - val_loss: 0.2735
# Epoch 67/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2708 - val_loss: 0.2733
# Epoch 68/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2707 - val_loss: 0.2737
# Epoch 69/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2707 - val_loss: 0.2733
# Epoch 70/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2706 - val_loss: 0.2737
# Epoch 71/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2706 - val_loss: 0.2731
# Epoch 72/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2705 - val_loss: 0.2731
# Epoch 73/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2705 - val_loss: 0.2731
# Epoch 74/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2704 - val_loss: 0.2732
# Epoch 75/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2704 - val_loss: 0.2730
# Epoch 76/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2704 - val_loss: 0.2729
# Epoch 77/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2703 - val_loss: 0.2730
# Epoch 78/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2703 - val_loss: 0.2730
# Epoch 79/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2702 - val_loss: 0.2730
# Epoch 80/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2702 - val_loss: 0.2728
# Epoch 81/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2702 - val_loss: 0.2728
# Epoch 82/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2701 - val_loss: 0.2727
# Epoch 83/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2701 - val_loss: 0.2727
# Epoch 84/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2700 - val_loss: 0.2727
# Epoch 85/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2700 - val_loss: 0.2726
# Epoch 86/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2700 - val_loss: 0.2727
# Epoch 87/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2699 - val_loss: 0.2726
# Epoch 88/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2699 - val_loss: 0.2727
# Epoch 89/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2699 - val_loss: 0.2725
# Epoch 90/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2698 - val_loss: 0.2724
# Epoch 91/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2698 - val_loss: 0.2726
# Epoch 92/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2698 - val_loss: 0.2723
# Epoch 93/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2697 - val_loss: 0.2727
# Epoch 94/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2697 - val_loss: 0.2724
# Epoch 95/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2696 - val_loss: 0.2724
# Epoch 96/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2697 - val_loss: 0.2723
# Epoch 97/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2696 - val_loss: 0.2722
# Epoch 98/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2696 - val_loss: 0.2723
# Epoch 99/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2696 - val_loss: 0.2723
# Epoch 100/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2695 - val_loss: 0.2724
# 313/313 [==============================] - 1s 3ms/step
# Epoch 1/100
# 235/235 [==============================] - 5s 16ms/step - loss: 0.3756 - val_loss: 0.3227
# Epoch 2/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.3124 - val_loss: 0.3093
# Epoch 3/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3031 - val_loss: 0.3029
# Epoch 4/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2979 - val_loss: 0.2986
# Epoch 5/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2947 - val_loss: 0.2955
# Epoch 6/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2922 - val_loss: 0.2936
# Epoch 7/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2905 - val_loss: 0.2929
# Epoch 8/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2891 - val_loss: 0.2907
# Epoch 9/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2879 - val_loss: 0.2903
# Epoch 10/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2871 - val_loss: 0.2890
# Epoch 11/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2863 - val_loss: 0.2884
# Epoch 12/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2856 - val_loss: 0.2882
# Epoch 13/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2850 - val_loss: 0.2873
# Epoch 14/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2845 - val_loss: 0.2867
# Epoch 15/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2841 - val_loss: 0.2863
# Epoch 16/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2836 - val_loss: 0.2861
# Epoch 17/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2832 - val_loss: 0.2857
# Epoch 18/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2829 - val_loss: 0.2855
# Epoch 19/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2826 - val_loss: 0.2851
# Epoch 20/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2823 - val_loss: 0.2848
# Epoch 21/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2821 - val_loss: 0.2852
# Epoch 22/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2819 - val_loss: 0.2848
# Epoch 23/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2816 - val_loss: 0.2849
# Epoch 24/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2814 - val_loss: 0.2844
# Epoch 25/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2813 - val_loss: 0.2846
# Epoch 26/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2811 - val_loss: 0.2837
# Epoch 27/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2809 - val_loss: 0.2838
# Epoch 28/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2808 - val_loss: 0.2838
# Epoch 29/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2807 - val_loss: 0.2834
# Epoch 30/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2805 - val_loss: 0.2832
# Epoch 31/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2804 - val_loss: 0.2832
# Epoch 32/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2803 - val_loss: 0.2830
# Epoch 33/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2802 - val_loss: 0.2830
# Epoch 34/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2800 - val_loss: 0.2828
# Epoch 35/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2799 - val_loss: 0.2827
# Epoch 36/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2798 - val_loss: 0.2828
# Epoch 37/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2797 - val_loss: 0.2827
# Epoch 38/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2796 - val_loss: 0.2824
# Epoch 39/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2795 - val_loss: 0.2823
# Epoch 40/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2794 - val_loss: 0.2824
# Epoch 41/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2793 - val_loss: 0.2825
# Epoch 42/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2792 - val_loss: 0.2824
# Epoch 43/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2792 - val_loss: 0.2822
# Epoch 44/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2791 - val_loss: 0.2820
# Epoch 45/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2790 - val_loss: 0.2819
# Epoch 46/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2789 - val_loss: 0.2820
# Epoch 47/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2788 - val_loss: 0.2819
# Epoch 48/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2787 - val_loss: 0.2818
# Epoch 49/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2786 - val_loss: 0.2818
# Epoch 50/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2786 - val_loss: 0.2819
# Epoch 51/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2785 - val_loss: 0.2817
# Epoch 52/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2785 - val_loss: 0.2816
# Epoch 53/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2784 - val_loss: 0.2814
# Epoch 54/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2784 - val_loss: 0.2814
# Epoch 55/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2783 - val_loss: 0.2813
# Epoch 56/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2783 - val_loss: 0.2813
# Epoch 57/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2781 - val_loss: 0.2815
# Epoch 58/100
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2782 - val_loss: 0.2816
# Epoch 59/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2781 - val_loss: 0.2814
# Epoch 60/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2780 - val_loss: 0.2814
# Epoch 61/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2780 - val_loss: 0.2812
# Epoch 62/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2779 - val_loss: 0.2812
# Epoch 63/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2779 - val_loss: 0.2814
# Epoch 64/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2778 - val_loss: 0.2811
# Epoch 65/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2778 - val_loss: 0.2810
# Epoch 66/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2778 - val_loss: 0.2809
# Epoch 67/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2777 - val_loss: 0.2809
# Epoch 68/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2777 - val_loss: 0.2811
# Epoch 69/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2776 - val_loss: 0.2809
# Epoch 70/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2776 - val_loss: 0.2809
# Epoch 71/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.2776 - val_loss: 0.2808
# Epoch 72/100
# 235/235 [==============================] - 5s 20ms/step - loss: 0.2775 - val_loss: 0.2808
# Epoch 73/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2775 - val_loss: 0.2807
# Epoch 74/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2774 - val_loss: 0.2811
# Epoch 75/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2774 - val_loss: 0.2808
# Epoch 76/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2774 - val_loss: 0.2808
# Epoch 77/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2773 - val_loss: 0.2807
# Epoch 78/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2773 - val_loss: 0.2807
# Epoch 79/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2773 - val_loss: 0.2806
# Epoch 80/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2772 - val_loss: 0.2805
# Epoch 81/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2772 - val_loss: 0.2805
# Epoch 82/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2772 - val_loss: 0.2804
# Epoch 83/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2771 - val_loss: 0.2804
# Epoch 84/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2771 - val_loss: 0.2805
# Epoch 85/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2771 - val_loss: 0.2804
# Epoch 86/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2770 - val_loss: 0.2804
# Epoch 87/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2770 - val_loss: 0.2803
# Epoch 88/100
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2770 - val_loss: 0.2804
# Epoch 89/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2770 - val_loss: 0.2803
# Epoch 90/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2769 - val_loss: 0.2803
# Epoch 91/100
# 235/235 [==============================] - 4s 19ms/step - loss: 0.2770 - val_loss: 0.2802
# Epoch 92/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.2769 - val_loss: 0.2803
# Epoch 93/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2768 - val_loss: 0.2803
# Epoch 94/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2768 - val_loss: 0.2802
# Epoch 95/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2768 - val_loss: 0.2802
# Epoch 96/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2768 - val_loss: 0.2800
# Epoch 97/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2768 - val_loss: 0.2801
# Epoch 98/100
# 235/235 [==============================] - 5s 22ms/step - loss: 0.2767 - val_loss: 0.2801
# Epoch 99/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2767 - val_loss: 0.2802
# Epoch 100/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.2767 - val_loss: 0.2800
# 313/313 [==============================] - 1s 2ms/step
